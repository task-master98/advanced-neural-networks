# %% [markdown]
# ## **Hyperparameter Tuning Pipeline**
# This notebook will be used to run the hyperparameter tuning pipeline for any experiment.

# %%
import sys
sys.path.append("/home/jupyter-iroy2/advanced-neural-networks")

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import os
from tqdm import tqdm
import optuna
from optuna.trial import TrialState

import advanced_neural_networks
from advanced_neural_networks.hp_tuning_main import objective

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "MIG-8657ad57-c1e5-5b9e-91c8-492b2a0bd0ff"
# Out:
# 2024-02-02 01:04:13.711066: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-02 01:04:13.711114: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-02 01:04:13.711858: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-02 01:04:13.716591: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## **Instructions to Use**
# 1. To configure the batch size and the number of epochs, change the values in the `trainer_config.yaml` file.
# 2. In order to change the configurations of the model architecture, modify values in the `hp_tuning.py` file. This needs a separate configuration file (TODO).
# 3. Set the number of trials and run the 4th cell.

# %%
random_seed = 1
torch.backends.cudnn.enabled = False  # Disable cuDNN use of nondeterministic algorithms
torch.manual_seed(random_seed)

# %%
def callback(study, trial):
    if study.best_trial.number == trial.number:
        study.set_user_attr(key="best_model", value=trial.user_attrs["best_model"])

# %%
study = optuna.create_study(direction = "maximize")
number_of_trials = 25
study.optimize(objective, n_trials=number_of_trials, callbacks=[callback])
# Out:
# [I 2024-02-02 01:04:15,566] A new study created in memory with name: no-name-19660786-af41-4385-a09b-d4bfa8c948b2
# /home/jupyter-iroy2/advanced-neural-networks/advanced_neural_networks/hp_tuning_main.py:48: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., step=...) instead.
#   out_channels_list = [int(trial.suggest_discrete_uniform("num_filters", 6, 32, 6)) for _ in range(num_conv_layers)]
# /home/jupyter-iroy2/.local/lib/python3.10/site-packages/optuna/distributions.py:685: UserWarning: The distribution is specified by [6, 32] and step=6, but the range is not divisible by `step`. It will be replaced by [6, 30.0].
#   warnings.warn(
# ...

# %%
pruned_trials = study.get_trials(deepcopy=False, states=[TrialState.PRUNED])
complete_trials = study.get_trials(deepcopy=False, states=[TrialState.COMPLETE])

print("Study statistics: ")
print("  Number of finished trials: ", len(study.trials))
print("  Number of pruned trials: ", len(pruned_trials))
print("  Number of complete trials: ", len(complete_trials))

print("Best trial:")
trial = study.best_trial

print("  Value: ", trial.value)

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Study statistics:
#   Number of finished trials:  16
#   Number of pruned trials:  0
#   Number of complete trials:  15
# Best trial:
#   Value:  0.9991688829787234
#   Params:
#     num_conv_layers: 2
#     num_filters: 30.0
#     pool_size: 2
#     n_linear_layers: 1
#     n_neurons: 100.0
#     optimizer: RMSprop
#     lr: 0.0007540036010940964

# %%
best_model = study.user_attrs["best_model"]
best_model
# Out:
# LeNet(
#   (conv_layers): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 30, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(30, 30, kernel_size=(3, 3), stride=(1, 1))
#       (1): ReLU()
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_layers): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=1080, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=100, out_features=10, bias=True)
#       (1): ReLU()
#     )
#   )
#   (softmax): Softmax(dim=1)
# )
